# %% [markdown]
# **SESIÓN 05** | MÁSTER UNIVERSITARIO EN CIENCIA DE DATOS | **CUNEF UNIVERSIDAD**
#
# `v2.2B`
# ---

# %% [markdown]
# # Predicción de Series Temporales
# ## VAR

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Packages

# %%
# Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.tsa.stattools import grangercausalitytests
from statsmodels.tsa.api import VAR
from statsmodels.tsa.base.datetools import dates_from_str

# %%
# Importamos la libreria de gráficos Seaborn
import seaborn as sns
sns.set(rc={'figure.figsize':(8, 3)})

# %% [markdown]
# ## Datos
# Seleccionamos del COVID

# %%
#mdata = sm.datasets.macrodata.load_pandas().data
mdata= pd.read_excel("UAE.xlsx")

#mdata=pd.read_csv("CP/owid-covid-data.xlsx",sep=';')

# %%
mdata.head()
# Out:
#   iso_code continent              location        date  total_cases  \
# 0      ARE      Asia  United Arab Emirates  2020-01-29            4
# 1      ARE      Asia  United Arab Emirates  2020-01-30            4
# 2      ARE      Asia  United Arab Emirates  2020-01-31            4
# 3      ARE      Asia  United Arab Emirates  2020-02-01            4
# 4      ARE      Asia  United Arab Emirates  2020-02-02            5
#
#    new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0          4                 NaN           NaN         NaN
# 1          0                 NaN           NaN         NaN
# 2          0                 NaN           NaN         NaN
# 3          0                 NaN           NaN         NaN
# 4          1                 NaN           NaN         NaN
#
#    new_deaths_smoothed  ...  female_smokers  male_smokers  \
# 0                  NaN  ...             1.2          37.4
# 1                  NaN  ...             1.2          37.4
# 2                  NaN  ...             1.2          37.4
# 3                  NaN  ...             1.2          37.4
# 4                  NaN  ...             1.2          37.4
#
#    handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                     NaN                         1.2            77.97
# 1                     NaN                         1.2            77.97
# 2                     NaN                         1.2            77.97
# 3                     NaN                         1.2            77.97
# 4                     NaN                         1.2            77.97
#
#    human_development_index  excess_mortality_cumulative_absolute  \
# 0                     0.89                                   NaN
# 1                     0.89                                   NaN
# 2                     0.89                                   NaN
# 3                     0.89                                   NaN
# 4                     0.89                                   NaN
#
#    excess_mortality_cumulative  excess_mortality  \
# 0                          NaN               NaN
# 1                          NaN               NaN
# 2                          NaN               NaN
# 3                          NaN               NaN
# 4                          NaN               NaN
#
#    excess_mortality_cumulative_per_million
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
# [5 rows x 67 columns]

# %%
pd.DatetimeIndex(dates_from_str(mdata['date']))
# Out:
# DatetimeIndex(['2020-01-29', '2020-01-30', '2020-01-31', '2020-02-01',
#                '2020-02-02', '2020-02-03', '2020-02-04', '2020-02-05',
#                '2020-02-06', '2020-02-07',
#                ...
#                '2022-10-04', '2022-10-05', '2022-10-06', '2022-10-07',
#                '2022-10-08', '2022-10-09', '2022-10-10', '2022-10-11',
#                '2022-10-12', '2022-10-13'],
#               dtype='datetime64[ns]', length=989, freq=None)

# %%
mdata=mdata[['date','new_cases','new_deaths']]
mdata.index = pd.DatetimeIndex(dates_from_str(mdata['date']))
mdata.drop('date', axis=1, inplace=True)
mdata
# Out:
#             new_cases  new_deaths
# 2020-01-29          4         NaN
# 2020-01-30          0         NaN
# 2020-01-31          0         NaN
# 2020-02-01          0         NaN
# 2020-02-02          1         NaN
# ...               ...         ...
# 2022-10-09        359         0.0
# 2022-10-10        342         0.0
# 2022-10-11        321         0.0
# 2022-10-12        337         0.0
# 2022-10-13        340         0.0
#
# [989 rows x 2 columns]

# %%
# select data from March 20, 2020, to March 20, 2021.
# train:  until March 10, 2021
# test: from March 11 toMarch 20, 2021

data_train=mdata['2020-03-20':'2021-03-10']
data_test=mdata['2021-03-11':'2021-03-20']

# %%
# Plot data 'new_cases'
data_train['new_cases'].plot(legend=True,label='TRAIN',marker='o')
data_test['new_cases'].plot(legend=True,label='TEST',figsize=(12,8),marker='o');

# %%
# Plot data 'new_deaths'
data_train['new_deaths'].plot(legend=True,label='TRAIN',marker='o')
data_test['new_deaths'].plot(legend=True,label='TEST',figsize=(12,8),marker='o');

# %%
# crear rolling mean 7 days
mdata_ma=mdata['2020-03-20':'2021-03-20'].rolling(7).mean()
data_train_ma=mdata_ma['2020-03-20':'2021-03-10']
data_test_ma=mdata_ma['2021-03-11':'2021-03-20']

# %%
# Plot data 'new_cases'
data_train_ma['new_cases'].plot(legend=True,label='TRAIN')
data_test_ma['new_cases'].plot(legend=True,label='TEST',figsize=(14,8));

# %%
# Plot data 'new_deaths'
data_train_ma['new_deaths'].plot(legend=True,label='TRAIN',)
data_test_ma['new_deaths'].plot(legend=True,label='TEST',figsize=(14,8));

# %%
# Transformacion estacionaria
# diferencia
d_data_train=data_train.diff().dropna()
d_data_train
# Out:
#             new_cases  new_deaths
# 2020-03-21       13.0        -2.0
# 2020-03-22      -13.0         0.0
# 2020-03-23       45.0         0.0
# 2020-03-24        5.0         0.0
# 2020-03-25       35.0         0.0
# ...               ...         ...
# 2021-03-06     -113.0         4.0
# 2021-03-07     -346.0        -2.0
# 2021-03-08     -130.0         1.0
# 2021-03-09     -110.0        -3.0
# 2021-03-10     -169.0        -2.0
#
# [355 rows x 2 columns]

# %%
# Plot data 'new_cases'
d_data_train['new_cases'].plot(legend=True,label='TRAIN')
# Out:
# <AxesSubplot: >

# %%
# Plot data 'new_deaths'
d_data_train['new_deaths'].plot(legend=True,label='TRAIN',)
# Out:
# <AxesSubplot: >

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
# plot
# satsmodels
plt.close()
fig = plt.figure(figsize=(14,5))
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

plot_acf(d_data_train['new_deaths'].dropna(), lags=40, ax=ax1)
ax1.set_title('AC', fontsize=10)

plot_pacf(d_data_train['new_deaths'].dropna(), lags=40, method='ywm', ax=ax2)
ax2.set_title('PAC ', fontsize=10)

plt.show()
plt.close()

# %% [markdown]
# ## Test de Causalidad de Granger
# Hasta 30 retardos

# %%
gc_res = grangercausalitytests(d_data_train[['new_cases','new_deaths']], 30)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0688  , p=0.7933  , df_denom=351, df_num=1
# ssr based chi2 test:   chi2=0.0694  , p=0.7923  , df=1
# likelihood ratio test: chi2=0.0694  , p=0.7923  , df=1
# parameter F test:         F=0.0688  , p=0.7933  , df_denom=351, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3504  , p=0.7047  , df_denom=348, df_num=2
# ssr based chi2 test:   chi2=0.7108  , p=0.7009  , df=2
# likelihood ratio test: chi2=0.7101  , p=0.7011  , df=2
# parameter F test:         F=0.3504  , p=0.7047  , df_denom=348, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7153  , p=0.5434  , df_denom=345, df_num=3
# ssr based chi2 test:   chi2=2.1895  , p=0.5340  , df=3
# likelihood ratio test: chi2=2.1827  , p=0.5354  , df=3
# parameter F test:         F=0.7153  , p=0.5434  , df_denom=345, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.1339  , p=0.3403  , df_denom=342, df_num=4
# ssr based chi2 test:   chi2=4.6550  , p=0.3246  , df=4
# likelihood ratio test: chi2=4.6244  , p=0.3280  , df=4
# parameter F test:         F=1.1339  , p=0.3403  , df_denom=342, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.7376  , p=0.5957  , df_denom=339, df_num=5
# ssr based chi2 test:   chi2=3.8078  , p=0.5774  , df=5
# likelihood ratio test: chi2=3.7872  , p=0.5804  , df=5
# parameter F test:         F=0.7376  , p=0.5957  , df_denom=339, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7735  , p=0.5912  , df_denom=336, df_num=6
# ssr based chi2 test:   chi2=4.8208  , p=0.5670  , df=6
# likelihood ratio test: chi2=4.7878  , p=0.5713  , df=6
# parameter F test:         F=0.7735  , p=0.5912  , df_denom=336, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.7083  , p=0.6650  , df_denom=333, df_num=7
# ssr based chi2 test:   chi2=5.1817  , p=0.6378  , df=7
# likelihood ratio test: chi2=5.1435  , p=0.6425  , df=7
# parameter F test:         F=0.7083  , p=0.6650  , df_denom=333, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.4422  , p=0.8952  , df_denom=330, df_num=8
# ssr based chi2 test:   chi2=3.7195  , p=0.8815  , df=8
# likelihood ratio test: chi2=3.6997  , p=0.8831  , df=8
# parameter F test:         F=0.4422  , p=0.8952  , df_denom=330, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.5458  , p=0.8406  , df_denom=327, df_num=9
# ssr based chi2 test:   chi2=5.1973  , p=0.8168  , df=9
# likelihood ratio test: chi2=5.1587  , p=0.8203  , df=9
# parameter F test:         F=0.5458  , p=0.8406  , df_denom=327, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.5585  , p=0.8472  , df_denom=324, df_num=10
# ssr based chi2 test:   chi2=5.9473  , p=0.8197  , df=10
# likelihood ratio test: chi2=5.8966  , p=0.8239  , df=10
# parameter F test:         F=0.5585  , p=0.8472  , df_denom=324, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=0.6490  , p=0.7860  , df_denom=321, df_num=11
# ssr based chi2 test:   chi2=7.6505  , p=0.7442  , df=11
# likelihood ratio test: chi2=7.5667  , p=0.7515  , df=11
# parameter F test:         F=0.6490  , p=0.7860  , df_denom=321, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.7139  , p=0.7379  , df_denom=318, df_num=12
# ssr based chi2 test:   chi2=9.2401  , p=0.6823  , df=12
# likelihood ratio test: chi2=9.1178  , p=0.6928  , df=12
# parameter F test:         F=0.7139  , p=0.7379  , df_denom=318, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=0.8825  , p=0.5721  , df_denom=315, df_num=13
# ssr based chi2 test:   chi2=12.4552 , p=0.4907  , df=13
# likelihood ratio test: chi2=12.2337 , p=0.5086  , df=13
# parameter F test:         F=0.8825  , p=0.5721  , df_denom=315, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=0.9897  , p=0.4636  , df_denom=312, df_num=14
# ssr based chi2 test:   chi2=15.1433 , p=0.3684  , df=14
# likelihood ratio test: chi2=14.8167 , p=0.3908  , df=14
# parameter F test:         F=0.9897  , p=0.4636  , df_denom=312, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=1.0550  , p=0.3986  , df_denom=309, df_num=15
# ssr based chi2 test:   chi2=17.4120 , p=0.2948  , df=15
# likelihood ratio test: chi2=16.9808 , p=0.3200  , df=15
# parameter F test:         F=1.0550  , p=0.3986  , df_denom=309, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=0.9933  , p=0.4638  , df_denom=306, df_num=16
# ssr based chi2 test:   chi2=17.6063 , p=0.3474  , df=16
# likelihood ratio test: chi2=17.1644 , p=0.3750  , df=16
# parameter F test:         F=0.9933  , p=0.4638  , df_denom=306, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=0.9166  , p=0.5546  , df_denom=303, df_num=17
# ssr based chi2 test:   chi2=17.3829 , p=0.4287  , df=17
# likelihood ratio test: chi2=16.9506 , p=0.4577  , df=17
# parameter F test:         F=0.9166  , p=0.5546  , df_denom=303, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=0.9596  , p=0.5069  , df_denom=300, df_num=18
# ssr based chi2 test:   chi2=19.4021 , p=0.3675  , df=18
# likelihood ratio test: chi2=18.8642 , p=0.4002  , df=18
# parameter F test:         F=0.9596  , p=0.5069  , df_denom=300, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=1.0371  , p=0.4179  , df_denom=297, df_num=19
# ssr based chi2 test:   chi2=22.2916 , p=0.2700  , df=19
# likelihood ratio test: chi2=21.5833 , p=0.3055  , df=19
# parameter F test:         F=1.0371  , p=0.4179  , df_denom=297, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=1.0528  , p=0.4000  , df_denom=294, df_num=20
# ssr based chi2 test:   chi2=23.9930 , p=0.2427  , df=20
# likelihood ratio test: chi2=23.1727 , p=0.2804  , df=20
# parameter F test:         F=1.0528  , p=0.4000  , df_denom=294, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=0.9527  , p=0.5230  , df_denom=291, df_num=21
# ssr based chi2 test:   chi2=22.9626 , p=0.3460  , df=21
# likelihood ratio test: chi2=22.2076 , p=0.3876  , df=21
# parameter F test:         F=0.9527  , p=0.5230  , df_denom=291, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=0.9999  , p=0.4644  , df_denom=288, df_num=22
# ssr based chi2 test:   chi2=25.4343 , p=0.2768  , df=22
# likelihood ratio test: chi2=24.5097 , p=0.3211  , df=22
# parameter F test:         F=0.9999  , p=0.4644  , df_denom=288, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=0.9497  , p=0.5316  , df_denom=285, df_num=23
# ssr based chi2 test:   chi2=25.4463 , p=0.3277  , df=23
# likelihood ratio test: chi2=24.5183 , p=0.3756  , df=23
# parameter F test:         F=0.9497  , p=0.5316  , df_denom=285, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=0.9409  , p=0.5459  , df_denom=282, df_num=24
# ssr based chi2 test:   chi2=26.5068 , p=0.3280  , df=24
# likelihood ratio test: chi2=25.4989 , p=0.3791  , df=24
# parameter F test:         F=0.9409  , p=0.5459  , df_denom=282, df_num=24
#
# Granger Causality
# number of lags (no zero) 25
# ssr based F test:         F=0.9367  , p=0.5542  , df_denom=279, df_num=25
# ssr based chi2 test:   chi2=27.6987 , p=0.3219  , df=25
# likelihood ratio test: chi2=26.5975 , p=0.3763  , df=25
# parameter F test:         F=0.9367  , p=0.5542  , df_denom=279, df_num=25
#
# Granger Causality
# number of lags (no zero) 26
# ssr based F test:         F=1.1186  , p=0.3187  , df_denom=276, df_num=26
# ssr based chi2 test:   chi2=34.6691 , p=0.1190  , df=26
# likelihood ratio test: chi2=32.9614 , p=0.1632  , df=26
# parameter F test:         F=1.1186  , p=0.3187  , df_denom=276, df_num=26
#
# Granger Causality
# number of lags (no zero) 27
# ssr based F test:         F=1.0598  , p=0.3887  , df_denom=273, df_num=27
# ssr based chi2 test:   chi2=34.3804 , p=0.1553  , df=27
# likelihood ratio test: chi2=32.6953 , p=0.2073  , df=27
# parameter F test:         F=1.0598  , p=0.3887  , df_denom=273, df_num=27
#
# Granger Causality
# number of lags (no zero) 28
# ssr based F test:         F=1.1161  , p=0.3184  , df_denom=270, df_num=28
# ssr based chi2 test:   chi2=37.8487 , p=0.1013  , df=28
# likelihood ratio test: chi2=35.8139 , p=0.1474  , df=28
# parameter F test:         F=1.1161  , p=0.3184  , df_denom=270, df_num=28
#
# Granger Causality
# number of lags (no zero) 29
# ssr based F test:         F=1.1772  , p=0.2497  , df_denom=267, df_num=29
# ssr based chi2 test:   chi2=41.6817 , p=0.0600  , df=29
# likelihood ratio test: chi2=39.2244 , p=0.0974  , df=29
# parameter F test:         F=1.1772  , p=0.2497  , df_denom=267, df_num=29
#
# Granger Causality
# number of lags (no zero) 30
# ssr based F test:         F=1.1352  , p=0.2932  , df_denom=264, df_num=30
# ssr based chi2 test:   chi2=41.9237 , p=0.0727  , df=30
# likelihood ratio test: chi2=39.4318 , p=0.1163  , df=30
# parameter F test:         F=1.1352  , p=0.2932  , df_denom=264, df_num=30

# %%
gc_res = grangercausalitytests(d_data_train[['new_deaths','new_cases']], 30)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.6534  , p=0.4195  , df_denom=351, df_num=1
# ssr based chi2 test:   chi2=0.6590  , p=0.4169  , df=1
# likelihood ratio test: chi2=0.6584  , p=0.4171  , df=1
# parameter F test:         F=0.6534  , p=0.4195  , df_denom=351, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.6030  , p=0.0283  , df_denom=348, df_num=2
# ssr based chi2 test:   chi2=7.3096  , p=0.0259  , df=2
# likelihood ratio test: chi2=7.2350  , p=0.0269  , df=2
# parameter F test:         F=3.6030  , p=0.0283  , df_denom=348, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.6786  , p=0.0469  , df_denom=345, df_num=3
# ssr based chi2 test:   chi2=8.1988  , p=0.0421  , df=3
# likelihood ratio test: chi2=8.1047  , p=0.0439  , df=3
# parameter F test:         F=2.6786  , p=0.0469  , df_denom=345, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.2419  , p=0.0642  , df_denom=342, df_num=4
# ssr based chi2 test:   chi2=9.2035  , p=0.0562  , df=4
# likelihood ratio test: chi2=9.0849  , p=0.0590  , df=4
# parameter F test:         F=2.2419  , p=0.0642  , df_denom=342, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.3759  , p=0.0387  , df_denom=339, df_num=5
# ssr based chi2 test:   chi2=12.2650 , p=0.0313  , df=5
# likelihood ratio test: chi2=12.0550 , p=0.0340  , df=5
# parameter F test:         F=2.3759  , p=0.0387  , df_denom=339, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.0572  , p=0.0578  , df_denom=336, df_num=6
# ssr based chi2 test:   chi2=12.8210 , p=0.0460  , df=6
# likelihood ratio test: chi2=12.5912 , p=0.0500  , df=6
# parameter F test:         F=2.0572  , p=0.0578  , df_denom=336, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.9752  , p=0.0578  , df_denom=333, df_num=7
# ssr based chi2 test:   chi2=14.4493 , p=0.0437  , df=7
# likelihood ratio test: chi2=14.1574 , p=0.0485  , df=7
# parameter F test:         F=1.9752  , p=0.0578  , df_denom=333, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.9455  , p=0.0528  , df_denom=330, df_num=8
# ssr based chi2 test:   chi2=16.3659 , p=0.0374  , df=8
# likelihood ratio test: chi2=15.9917 , p=0.0425  , df=8
# parameter F test:         F=1.9455  , p=0.0528  , df_denom=330, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.0349  , p=0.0351  , df_denom=327, df_num=9
# ssr based chi2 test:   chi2=19.3782 , p=0.0222  , df=9
# likelihood ratio test: chi2=18.8550 , p=0.0265  , df=9
# parameter F test:         F=2.0349  , p=0.0351  , df_denom=327, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.5714  , p=0.0053  , df_denom=324, df_num=10
# ssr based chi2 test:   chi2=27.3810 , p=0.0023  , df=10
# likelihood ratio test: chi2=26.3487 , p=0.0033  , df=10
# parameter F test:         F=2.5714  , p=0.0053  , df_denom=324, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=2.5416  , p=0.0043  , df_denom=321, df_num=11
# ssr based chi2 test:   chi2=29.9607 , p=0.0016  , df=11
# likelihood ratio test: chi2=28.7271 , p=0.0025  , df=11
# parameter F test:         F=2.5416  , p=0.0043  , df_denom=321, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=2.3415  , p=0.0069  , df_denom=318, df_num=12
# ssr based chi2 test:   chi2=30.3067 , p=0.0025  , df=12
# likelihood ratio test: chi2=29.0418 , p=0.0039  , df=12
# parameter F test:         F=2.3415  , p=0.0069  , df_denom=318, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=2.4182  , p=0.0040  , df_denom=315, df_num=13
# ssr based chi2 test:   chi2=34.1307 , p=0.0011  , df=13
# likelihood ratio test: chi2=32.5331 , p=0.0020  , df=13
# parameter F test:         F=2.4182  , p=0.0040  , df_denom=315, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=2.5375  , p=0.0019  , df_denom=312, df_num=14
# ssr based chi2 test:   chi2=38.8276 , p=0.0004  , df=14
# likelihood ratio test: chi2=36.7717 , p=0.0008  , df=14
# parameter F test:         F=2.5375  , p=0.0019  , df_denom=312, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=2.6019  , p=0.0011  , df_denom=309, df_num=15
# ssr based chi2 test:   chi2=42.9447 , p=0.0002  , df=15
# likelihood ratio test: chi2=40.4413 , p=0.0004  , df=15
# parameter F test:         F=2.6019  , p=0.0011  , df_denom=309, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=2.5313  , p=0.0011  , df_denom=306, df_num=16
# ssr based chi2 test:   chi2=44.8692 , p=0.0001  , df=16
# likelihood ratio test: chi2=42.1383 , p=0.0004  , df=16
# parameter F test:         F=2.5313  , p=0.0011  , df_denom=306, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=2.6183  , p=0.0006  , df_denom=303, df_num=17
# ssr based chi2 test:   chi2=49.6534 , p=0.0000  , df=17
# likelihood ratio test: chi2=46.3283 , p=0.0002  , df=17
# parameter F test:         F=2.6183  , p=0.0006  , df_denom=303, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=2.4676  , p=0.0009  , df_denom=300, df_num=18
# ssr based chi2 test:   chi2=49.8952 , p=0.0001  , df=18
# likelihood ratio test: chi2=46.5299 , p=0.0002  , df=18
# parameter F test:         F=2.4676  , p=0.0009  , df_denom=300, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=2.4153  , p=0.0010  , df_denom=297, df_num=19
# ssr based chi2 test:   chi2=51.9169 , p=0.0001  , df=19
# likelihood ratio test: chi2=48.2765 , p=0.0002  , df=19
# parameter F test:         F=2.4153  , p=0.0010  , df_denom=297, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=2.2954  , p=0.0015  , df_denom=294, df_num=20
# ssr based chi2 test:   chi2=52.3103 , p=0.0001  , df=20
# likelihood ratio test: chi2=48.6070 , p=0.0003  , df=20
# parameter F test:         F=2.2954  , p=0.0015  , df_denom=294, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=2.1293  , p=0.0032  , df_denom=291, df_num=21
# ssr based chi2 test:   chi2=51.3230 , p=0.0002  , df=21
# likelihood ratio test: chi2=47.7423 , p=0.0007  , df=21
# parameter F test:         F=2.1293  , p=0.0032  , df_denom=291, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=2.0126  , p=0.0053  , df_denom=288, df_num=22
# ssr based chi2 test:   chi2=51.1960 , p=0.0004  , df=22
# likelihood ratio test: chi2=47.6224 , p=0.0012  , df=22
# parameter F test:         F=2.0126  , p=0.0053  , df_denom=288, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=2.0175  , p=0.0045  , df_denom=285, df_num=23
# ssr based chi2 test:   chi2=54.0536 , p=0.0003  , df=23
# likelihood ratio test: chi2=50.0793 , p=0.0009  , df=23
# parameter F test:         F=2.0175  , p=0.0045  , df_denom=285, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=2.0986  , p=0.0024  , df_denom=282, df_num=24
# ssr based chi2 test:   chi2=59.1190 , p=0.0001  , df=24
# likelihood ratio test: chi2=54.3944 , p=0.0004  , df=24
# parameter F test:         F=2.0986  , p=0.0024  , df_denom=282, df_num=24
#
# Granger Causality
# number of lags (no zero) 25
# ssr based F test:         F=2.0117  , p=0.0036  , df_denom=279, df_num=25
# ssr based chi2 test:   chi2=59.4844 , p=0.0001  , df=25
# likelihood ratio test: chi2=54.6913 , p=0.0005  , df=25
# parameter F test:         F=2.0117  , p=0.0036  , df_denom=279, df_num=25
#
# Granger Causality
# number of lags (no zero) 26
# ssr based F test:         F=1.9109  , p=0.0060  , df_denom=276, df_num=26
# ssr based chi2 test:   chi2=59.2253 , p=0.0002  , df=26
# likelihood ratio test: chi2=54.4587 , p=0.0009  , df=26
# parameter F test:         F=1.9109  , p=0.0060  , df_denom=276, df_num=26
#
# Granger Causality
# number of lags (no zero) 27
# ssr based F test:         F=2.1824  , p=0.0009  , df_denom=273, df_num=27
# ssr based chi2 test:   chi2=70.7960 , p=0.0000  , df=27
# likelihood ratio test: chi2=64.1031 , p=0.0001  , df=27
# parameter F test:         F=2.1824  , p=0.0009  , df_denom=273, df_num=27
#
# Granger Causality
# number of lags (no zero) 28
# ssr based F test:         F=2.4033  , p=0.0002  , df_denom=270, df_num=28
# ssr based chi2 test:   chi2=81.4987 , p=0.0000  , df=28
# likelihood ratio test: chi2=72.7668 , p=0.0000  , df=28
# parameter F test:         F=2.4033  , p=0.0002  , df_denom=270, df_num=28
#
# Granger Causality
# number of lags (no zero) 29
# ssr based F test:         F=2.3195  , p=0.0003  , df_denom=267, df_num=29
# ssr based chi2 test:   chi2=82.1287 , p=0.0000  , df=29
# likelihood ratio test: chi2=73.2474 , p=0.0000  , df=29
# parameter F test:         F=2.3195  , p=0.0003  , df_denom=267, df_num=29
#
# Granger Causality
# number of lags (no zero) 30
# ssr based F test:         F=2.2119  , p=0.0005  , df_denom=264, df_num=30
# ssr based chi2 test:   chi2=81.6904 , p=0.0000  , df=30
# likelihood ratio test: chi2=72.8738 , p=0.0000  , df=30
# parameter F test:         F=2.2119  , p=0.0005  , df_denom=264, df_num=30

# %% [markdown]
# ## Modelo VAR

# %%
# definir el VAR
model = VAR(d_data_train)
# maximo lag a seleccionar
model.select_order(30)
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
# estimar los modelos y seleccionar
results = model.fit(maxlags=30, ic='aic')

# %%
# lag con menor AIC
results.k_ar
# Out:
# 28

# %%
# El modelo estimado
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 08, Oct, 2023
# Time:                     11:20:42
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    12.9519
# Nobs:                     327.000    HQIC:                   12.1578
# Log likelihood:          -2715.59    FPE:                    113301.
# AIC:                      11.6306    Det(Omega_mle):         82160.9
# --------------------------------------------------------------------
# Results for equation new_cases
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  6.684797         9.838235            0.679           0.497
# L1.new_cases          -0.201190         0.060886           -3.304           0.001
# L1.new_deaths         -1.004281         5.373333           -0.187           0.852
# L2.new_cases          -0.279105         0.062130           -4.492           0.000
# L2.new_deaths          0.661941         6.690206            0.099           0.921
# L3.new_cases          -0.127085         0.064375           -1.974           0.048
# L3.new_deaths         -5.655363         7.315171           -0.773           0.439
# L4.new_cases          -0.155834         0.065136           -2.392           0.017
# L4.new_deaths         -0.104310         7.580238           -0.014           0.989
# L5.new_cases          -0.014771         0.066235           -0.223           0.824
# L5.new_deaths         -2.700782         7.762845           -0.348           0.728
# L6.new_cases          -0.009652         0.065963           -0.146           0.884
# L6.new_deaths          1.769933         7.780909            0.227           0.820
# L7.new_cases           0.244661         0.066203            3.696           0.000
# L7.new_deaths         -3.782248         7.747400           -0.488           0.625
# L8.new_cases           0.223213         0.067848            3.290           0.001
# L8.new_deaths          0.448502         7.720108            0.058           0.954
# L9.new_cases           0.252693         0.069308            3.646           0.000
# L9.new_deaths          5.795226         7.702838            0.752           0.452
# L10.new_cases          0.042765         0.069887            0.612           0.541
# L10.new_deaths         4.632153         7.692510            0.602           0.547
# L11.new_cases          0.152980         0.069279            2.208           0.027
# L11.new_deaths         7.328674         7.767630            0.943           0.345
# L12.new_cases         -0.013726         0.070632           -0.194           0.846
# L12.new_deaths        -0.032020         7.853947           -0.004           0.997
# L13.new_cases          0.009193         0.072071            0.128           0.899
# L13.new_deaths        -6.680641         7.854364           -0.851           0.395
# L14.new_cases          0.070726         0.072183            0.980           0.327
# L14.new_deaths        -1.063825         7.867239           -0.135           0.892
# L15.new_cases          0.011509         0.072639            0.158           0.874
# L15.new_deaths         8.976041         7.901594            1.136           0.256
# L16.new_cases         -0.098579         0.074126           -1.330           0.184
# L16.new_deaths        11.045322         7.952659            1.389           0.165
# L17.new_cases          0.052914         0.074390            0.711           0.477
# L17.new_deaths         8.228669         8.014556            1.027           0.305
# L18.new_cases         -0.055630         0.075306           -0.739           0.460
# L18.new_deaths         8.411589         7.970939            1.055           0.291
# L19.new_cases         -0.134058         0.074878           -1.790           0.073
# L19.new_deaths        -0.370591         7.924715           -0.047           0.963
# L20.new_cases          0.067135         0.075803            0.886           0.376
# L20.new_deaths        -7.447018         7.973892           -0.934           0.350
# L21.new_cases          0.200808         0.075562            2.658           0.008
# L21.new_deaths        -2.743478         8.040189           -0.341           0.733
# L22.new_cases          0.026436         0.074661            0.354           0.723
# L22.new_deaths       -12.200121         8.065633           -1.513           0.130
# L23.new_cases         -0.137075         0.074763           -1.833           0.067
# L23.new_deaths        -3.878447         8.090247           -0.479           0.632
# L24.new_cases         -0.041835         0.075341           -0.555           0.579
# L24.new_deaths        -9.023689         8.051491           -1.121           0.262
# L25.new_cases         -0.106814         0.078091           -1.368           0.171
# L25.new_deaths        -7.164776         7.990976           -0.897           0.370
# L26.new_cases         -0.163752         0.078823           -2.077           0.038
# L26.new_deaths        -9.749652         7.873929           -1.238           0.216
# L27.new_cases          0.025091         0.077230            0.325           0.745
# L27.new_deaths         7.077590         7.322003            0.967           0.334
# L28.new_cases         -0.050210         0.076610           -0.655           0.512
# L28.new_deaths        11.309683         6.174575            1.832           0.067
# =================================================================================
#
# Results for equation new_deaths
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 -0.041017         0.110249           -0.372           0.710
# L1.new_cases          -0.000281         0.000682           -0.412           0.681
# L1.new_deaths         -0.779067         0.060214          -12.938           0.000
# L2.new_cases           0.001729         0.000696            2.483           0.013
# L2.new_deaths         -0.578373         0.074971           -7.715           0.000
# L3.new_cases           0.001059         0.000721            1.468           0.142
# L3.new_deaths         -0.387833         0.081975           -4.731           0.000
# L4.new_cases           0.000737         0.000730            1.010           0.313
# L4.new_deaths         -0.390540         0.084945           -4.598           0.000
# L5.new_cases           0.000523         0.000742            0.704           0.481
# L5.new_deaths         -0.259919         0.086992           -2.988           0.003
# L6.new_cases           0.001116         0.000739            1.510           0.131
# L6.new_deaths         -0.069766         0.087194           -0.800           0.424
# L7.new_cases           0.000941         0.000742            1.269           0.205
# L7.new_deaths         -0.037162         0.086819           -0.428           0.669
# L8.new_cases           0.001280         0.000760            1.683           0.092
# L8.new_deaths         -0.019044         0.086513           -0.220           0.826
# L9.new_cases          -0.000002         0.000777           -0.002           0.998
# L9.new_deaths         -0.086811         0.086319           -1.006           0.315
# L10.new_cases          0.000444         0.000783            0.567           0.571
# L10.new_deaths         0.160377         0.086203            1.860           0.063
# L11.new_cases         -0.001286         0.000776           -1.657           0.098
# L11.new_deaths         0.172075         0.087045            1.977           0.048
# L12.new_cases         -0.000793         0.000792           -1.002           0.316
# L12.new_deaths         0.136500         0.088013            1.551           0.121
# L13.new_cases         -0.001121         0.000808           -1.388           0.165
# L13.new_deaths         0.140785         0.088017            1.600           0.110
# L14.new_cases         -0.001604         0.000809           -1.983           0.047
# L14.new_deaths         0.079359         0.088161            0.900           0.368
# L15.new_cases          0.001127         0.000814            1.384           0.166
# L15.new_deaths         0.114511         0.088546            1.293           0.196
# L16.new_cases         -0.000664         0.000831           -0.799           0.424
# L16.new_deaths         0.173641         0.089119            1.948           0.051
# L17.new_cases          0.000772         0.000834            0.927           0.354
# L17.new_deaths        -0.076393         0.089812           -0.851           0.395
# L18.new_cases         -0.000526         0.000844           -0.623           0.533
# L18.new_deaths         0.003522         0.089324            0.039           0.969
# L19.new_cases          0.000552         0.000839            0.658           0.510
# L19.new_deaths        -0.112178         0.088806           -1.263           0.207
# L20.new_cases         -0.001231         0.000849           -1.449           0.147
# L20.new_deaths        -0.113920         0.089357           -1.275           0.202
# L21.new_cases          0.000249         0.000847            0.294           0.769
# L21.new_deaths        -0.078397         0.090100           -0.870           0.384
# L22.new_cases          0.001028         0.000837            1.228           0.219
# L22.new_deaths        -0.125736         0.090385           -1.391           0.164
# L23.new_cases          0.001418         0.000838            1.692           0.091
# L23.new_deaths        -0.152811         0.090661           -1.686           0.092
# L24.new_cases          0.001811         0.000844            2.145           0.032
# L24.new_deaths        -0.174225         0.090226           -1.931           0.053
# L25.new_cases          0.001198         0.000875            1.369           0.171
# L25.new_deaths         0.022567         0.089548            0.252           0.801
# L26.new_cases          0.000926         0.000883            1.048           0.295
# L26.new_deaths         0.016235         0.088236            0.184           0.854
# L27.new_cases          0.002829         0.000865            3.269           0.001
# L27.new_deaths         0.085579         0.082051            1.043           0.297
# L28.new_cases          0.002251         0.000859            2.622           0.009
# L28.new_deaths         0.021352         0.069193            0.309           0.758
# =================================================================================
#
# Correlation matrix of residuals
#               new_cases  new_deaths
# new_cases      1.000000    0.000956
# new_deaths     0.000956    1.000000

# %% [markdown]
# ## Gráfico de los datos

# %%
results.plot();

# %% [markdown]
# ## Correlaciones de los residuos
#
# ¿Son ruido blanco?

# %%
results.plot_acorr();

# %% [markdown]
# ## Predicción
# ### Es necesario darle los valores iniciales, para la predicción recursiva.
# ### ES el orden del VAR

# %%
lag_order = results.k_ar
lag_order
# Out:
# 28

# %%
d_data_train.values[-lag_order:]
# Out:
# array([[ -14.,    9.],
#        [-218.,   -6.],
#        [-676.,    3.],
#        [ 536.,   -2.],
#        [ -44.,    0.],
#        [ 113.,    1.],
#        [ 216.,    0.],
#        [-158.,    4.],
#        [-154.,    2.],
#        [  18.,   -5.],
#        [-908.,    2.],
#        [-145.,   -2.],
#        [ 900.,  -10.],
#        [  97.,   14.],
#        [ -77.,   -1.],
#        [ 473.,   -2.],
#        [ -64.,   -1.],
#        [-504.,   -7.],
#        [-404.,    9.],
#        [ 195.,   -2.],
#        [ -29.,    1.],
#        [  50.,    1.],
#        [ 330.,   -7.],
#        [-113.,    4.],
#        [-346.,   -2.],
#        [-130.,    1.],
#        [-110.,   -3.],
#        [-169.,   -2.]])

# %%
# Hacemos 10 predicciones
results.forecast(d_data_train.values[-lag_order:], 10)
# Out:
# array([[  45.63327341,    2.13251232],
#        [ 282.5792349 ,    1.59258683],
#        [  50.45403495,   -1.22534525],
#        [-535.89049925,    4.2932861 ],
#        [-152.33135491,   -6.72214875],
#        [ 318.99195525,   -0.96927922],
#        [ 101.65420811,    3.35391105],
#        [ -63.97947186,   -2.90341147],
#        [ 414.85575383,    3.85530604],
#        [-205.25651008,   -4.59914708]])

# %%
results.plot_forecast(10);

# %%
results.forecast(d_data_train.values[-lag_order:], 10)
# Out:
# array([[  45.63327341,    2.13251232],
#        [ 282.5792349 ,    1.59258683],
#        [  50.45403495,   -1.22534525],
#        [-535.89049925,    4.2932861 ],
#        [-152.33135491,   -6.72214875],
#        [ 318.99195525,   -0.96927922],
#        [ 101.65420811,    3.35391105],
#        [ -63.97947186,   -2.90341147],
#        [ 414.85575383,    3.85530604],
#        [-205.25651008,   -4.59914708]])

# %%
np.cumsum(results.forecast(d_data_train.values[-lag_order:], 10),axis=0)
# Out:
# array([[ 4.56332734e+01,  2.13251232e+00],
#        [ 3.28212508e+02,  3.72509915e+00],
#        [ 3.78666543e+02,  2.49975390e+00],
#        [-1.57223956e+02,  6.79304001e+00],
#        [-3.09555311e+02,  7.08912586e-02],
#        [ 9.43664435e+00, -8.98387960e-01],
#        [ 1.11090852e+02,  2.45552309e+00],
#        [ 4.71113806e+01, -4.47888379e-01],
#        [ 4.61967134e+02,  3.40741766e+00],
#        [ 2.56710624e+02, -1.19172942e+00]])

# %%
# acumular las diferencias y sumar la valor inicial

f_data=data_train.values[-1:]+np.cumsum(results.forecast(d_data_train.values[-lag_order:], 10),axis=0)
f_data
# Out:
# array([[2249.63327341,   10.13251232],
#        [2532.2125083 ,   11.72509915],
#        [2582.66654325,   10.4997539 ],
#        [2046.776044  ,   14.79304001],
#        [1894.4446891 ,    8.07089126],
#        [2213.43664435,    7.10161204],
#        [2315.09085246,   10.45552309],
#        [2251.1113806 ,    7.55211162],
#        [2665.96713442,   11.40741766],
#        [2460.71062434,    6.80827058]])

# %%
data_fore=pd.DataFrame(f_data)
data_fore.index=data_test.index
data_fore.rename(columns={0: 'f_cases', 1: 'f_deaths'}, inplace=True)
data_fore
# Out:
#                 f_cases   f_deaths
# 2021-03-11  2249.633273  10.132512
# 2021-03-12  2532.212508  11.725099
# 2021-03-13  2582.666543  10.499754
# 2021-03-14  2046.776044  14.793040
# 2021-03-15  1894.444689   8.070891
# 2021-03-16  2213.436644   7.101612
# 2021-03-17  2315.090852  10.455523
# 2021-03-18  2251.111381   7.552112
# 2021-03-19  2665.967134  11.407418
# 2021-03-20  2460.710624   6.808271

# %%
data_train['new_cases'].plot(legend=True,label='TRAIN',)
data_fore['f_cases'].plot(legend=True,label='FORECAST')
data_test['new_cases'].plot(legend=True,label='TEST',figsize=(14,8));

# %%
data_train['new_deaths'].plot(legend=True,label='TRAIN',)
data_fore['f_deaths'].plot(legend=True,label='FORECAST')
data_test['new_deaths'].plot(legend=True,label='TEST',figsize=(14,8));

# %%
data_for_ma=pd.concat([data_train['new_deaths'],data_fore['f_deaths']],axis=0).rolling(7).mean().dropna()
data_for_ma=pd.DataFrame(data_for_ma)
data_for_ma.rename(columns={0: 'f_deaths'}, inplace=True)
data_for_ma
# Out:
#              f_deaths
# 2020-03-26   0.285714
# 2020-03-27   0.000000
# 2020-03-28   0.000000
# 2020-03-29   0.142857
# 2020-03-30   0.428571
# ...               ...
# 2021-03-16  10.046130
# 2021-03-17  10.396919
# 2021-03-18  10.028290
# 2021-03-19   9.982907
# 2021-03-20   9.455552
#
# [360 rows x 1 columns]

# %%
data_for_ma['f_deaths'].plot(legend=True,label='TRAIN',)
data_test_ma['new_deaths'].plot(legend=True,label='TEST',figsize=(14,8));

# %%
from statsmodels.tools.eval_measures import rmse
rmse(data_fore['f_deaths'],data_test['new_deaths'])
# Out:
# 4.2867591354070065

# %%
rmse(data_for_ma['f_deaths'][-10:],data_test_ma['new_deaths'])
# Out:
# 1.700744929727145

# %% [markdown]
# ## Función de Respuesta al Impulso

# %%
irf = results.irf(30)

# %%
irf.plot(orth=False);

# %% [markdown]
# ## Función de Respuesta al Impulso(Individual)

# %%
irf.plot(impulse='new_cases');

# %% [markdown]
# ## Función de Respuesta al Impulso ACUMULADA

# %%
irf.plot_cum_effects(orth=False);

# %% [markdown]
# ## Descomposición del error de predicción

# %%
fevd = results.fevd(30)

# %%
fevd.summary()
# Out:
# FEVD for new_cases
#       new_cases  new_deaths
# 0      1.000000    0.000000
# 1      0.999878    0.000122
# 2      0.999575    0.000425
# 3      0.995129    0.004871
# 4      0.992088    0.007912
# 5      0.991669    0.008331
# 6      0.990702    0.009298
# 7      0.989187    0.010813
# 8      0.988798    0.011202
# 9      0.985214    0.014786
# 10     0.984548    0.015452
# 11     0.983418    0.016582
# 12     0.979302    0.020698
# 13     0.973289    0.026711
# 14     0.968936    0.031064
# 15     0.957531    0.042469
# 16     0.956502    0.043498
# 17     0.956555    0.043445
# 18     0.956625    0.043375
# 19     0.949202    0.050798
# 20     0.946558    0.053442
# 21     0.945413    0.054587
# 22     0.944288    0.055712
# 23     0.941030    0.058970
# 24     0.940227    0.059773
# 25     0.940297    0.059703
# 26     0.940426    0.059574
# 27     0.931765    0.068235
# 28     0.932371    0.067629
# 29     0.926083    0.073917
#
# FEVD for new_deaths
#       new_cases  new_deaths
# 0      0.000001    0.999999
# 1      0.000415    0.999585
# 2      0.019905    0.980095
# 3      0.021710    0.978290
# 4      0.022430    0.977570
# 5      0.022375    0.977625
# 6      0.022907    0.977093
# 7      0.022854    0.977146
# 8      0.024847    0.975153
# 9      0.027543    0.972457
# 10     0.028052    0.971948
# 11     0.038673    0.961327
# 12     0.040103    0.959897
# 13     0.040415    0.959585
# 14     0.043449    0.956551
# 15     0.078978    0.921022
# 16     0.091571    0.908429
# 17     0.090815    0.909185
# 18     0.091362    0.908638
# 19     0.089694    0.910306
# 20     0.092812    0.907188
# 21     0.093639    0.906361
# 22     0.099582    0.900418
# 23     0.102148    0.897852
# 24     0.102090    0.897910
# 25     0.106370    0.893630
# 26     0.106577    0.893423
# 27     0.117626    0.882374
# 28     0.117663    0.882337
# 29     0.125429    0.874571

# %%
results.fevd(30).plot();
