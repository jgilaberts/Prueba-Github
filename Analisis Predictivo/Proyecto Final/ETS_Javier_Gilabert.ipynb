# %% [markdown]
# ## Predicción Reservas

# %% [markdown]
# ## Introducción
#
# <div class="exercise">
#
# - El objetivo es predecir las reservas del hotel.
#
# - Se realizan diferentes predicciones de las reservas.
#
# - Se tienen datos semanales desde 2015 hasta 2017-09-03.
#
# - Se dejan fuera de la estimación las 4 últimas semanas para seleccionar el mejor modelo.
#
# - Se prueban todos los modelos de suavizados exponencial.
#
# </div>

# %%
# Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Lectura
df_w_r = pd.read_csv('df_reservas.csv')
df_w_r['ArrivalDate'] = pd.to_datetime(df_w_r['ArrivalDate'])
df_w_r = df_w_r.set_index('ArrivalDate')
df_w_r.tail()
# Out:
#              IsCanceled
# ArrivalDate
# 2017-07-30          463
# 2017-08-06          452
# 2017-08-13          442
# 2017-08-20          465
# 2017-08-27          472

# %%
# Graficar Reservas
import seaborn as sns
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(11, 4)})
ax = df_w_r.plot(marker='o', linestyle='-')
ax.set_ylabel('Reservas Hotel');

# %% [markdown]
# Analisis Estacionalidad
#  - Componente estacional, meses con mayores reservas en octubre y descenso de las reservas durante el mes de enero

# %% [markdown]
# ## Modelo de Suavizado Exponencial

# %%
from sktime.forecasting.base import ForecastingHorizon
from sktime.utils.plotting import plot_series
from sktime.forecasting.model_selection import temporal_train_test_split

# %%
# Separamos la muestra entre train y test, vamos a predecir 4 periodos
y_train, y_test = temporal_train_test_split(y =df_w_r["IsCanceled"], test_size=4)
plot_series(y_train, y_test, labels=["y_train", "y_test"])
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# (<Figure size 1600x400 with 1 Axes>, <Axes: ylabel='IsCanceled'>)

# %%
from sktime.forecasting.ets import AutoETS

# %%
# step 2: specifying forecasting horizon
fh = np.arange(1, 5)

# step 3: specifying the forecasting algorithm (4) son los periodos que es trimestral
df_w_r_model = AutoETS(auto=True, sp=52, n_jobs=-1)

# %%
df_w_r_model.fit(y_train) # Se estima con los datos de train SO LO
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# AutoETS(auto=True, n_jobs=-1, sp=52)

# %%
print(df_w_r_model.summary())
# Out:
#                                  ETS Results
# ==============================================================================
# Dep. Variable:             IsCanceled   No. Observations:                  105
# Model:                      ETS(AAdA)   Log Likelihood                -539.121
# Date:                Thu, 21 Dec 2023   AIC                           1196.242
# Time:                        10:35:45   BIC                           1352.826
# Sample:                    08-02-2015   HQIC                          1259.693
#                          - 07-30-2017   Scale                         1687.651
# Covariance Type:               approx
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# smoothing_level         0.3885      0.262      1.484      0.138      -0.124       0.901
# smoothing_trend         0.0413      0.093      0.442      0.658      -0.142       0.224
# smoothing_seasonal   6.115e-05        nan        nan        nan         nan         nan
# damping_trend           0.8000      0.103      7.745      0.000       0.598       1.002
# initial_level         -14.0009    8.5e+04     -0.000      1.000   -1.67e+05    1.66e+05
# initial_trend         127.7064    110.819      1.152      0.249     -89.494     344.907
# initial_seasonal.0     23.6547    8.5e+04      0.000      1.000   -1.66e+05    1.67e+05
# initial_seasonal.1     23.7145    8.5e+04      0.000      1.000   -1.66e+05    1.67e+05
# initial_seasonal.2     17.8801    8.5e+04      0.000      1.000   -1.66e+05    1.67e+05
# initial_seasonal.3    -23.3211    8.5e+04     -0.000      1.000   -1.67e+05    1.66e+05
# initial_seasonal.4     38.5888    8.5e+04      0.000      1.000   -1.66e+05    1.67e+05
# initial_seasonal.5    -12.3066    8.5e+04     -0.000      1.000   -1.67e+05    1.66e+05
# initial_seasonal.6     18.1369    8.5e+04      0.000      1.000   -1.66e+05    1.67e+05
# initial_seasonal.7    -50.9604    8.5e+04     -0.001      1.000   -1.67e+05    1.66e+05
# initial_seasonal.8     -6.5434    8.5e+04   -7.7e-05      1.000   -1.67e+05    1.67e+05
# initial_seasonal.9     11.6677    8.5e+04      0.000      1.000   -1.66e+05    1.67e+05
# initial_seasonal.10   -22.3063    8.5e+04     -0.000      1.000   -1.67e+05    1.66e+05
# initial_seasonal.11   -47.1380    8.5e+04     -0.001      1.000   -1.67e+05    1.66e+05
# initial_seasonal.12   -79.9512    8.5e+04     -0.001      0.999   -1.67e+05    1.66e+05
# initial_seasonal.13   -91.4660    8.5e+04     -0.001      0.999   -1.67e+05    1.66e+05
# initial_seasonal.14   -74.6144    8.5e+04     -0.001      0.999   -1.67e+05    1.66e+05
# initial_seasonal.15   -49.8016    8.5e+04     -0.001      1.000   -1.67e+05    1.66e+05
# initial_seasonal.16  -106.7550    8.5e+04     -0.001      0.999   -1.67e+05    1.66e+05
# initial_seasonal.17   -93.2012    8.5e+04     -0.001      0.999   -1.67e+05    1.66e+05
# initial_seasonal.18   -48.1679    8.5e+04     -0.001      1.000   -1.67e+05    1.66e+05
# initial_seasonal.19   -81.0941    8.5e+04     -0.001      0.999   -1.67e+05    1.66e+05
# initial_seasonal.20  -102.1602    8.5e+04     -0.001      0.999   -1.67e+05    1.66e+05
# initial_seasonal.21   -78.3387    8.5e+04     -0.001      0.999   -1.67e+05    1.66e+05
# initial_seasonal.22  -107.9820    8.5e+04     -0.001      0.999   -1.67e+05    1.66e+05
# initial_seasonal.23  -155.1558    8.5e+04     -0.002      0.999   -1.67e+05    1.66e+05
# initial_seasonal.24  -176.2322    8.5e+04     -0.002      0.998   -1.67e+05    1.66e+05
# initial_seasonal.25  -229.6656    8.5e+04     -0.003      0.998   -1.67e+05    1.66e+05
# initial_seasonal.26  -191.4810    8.5e+04     -0.002      0.998   -1.67e+05    1.66e+05
# initial_seasonal.27  -247.0860    8.5e+04     -0.003      0.998   -1.67e+05    1.66e+05
# initial_seasonal.28  -230.1482    8.5e+04     -0.003      0.998   -1.67e+05    1.66e+05
# initial_seasonal.29   -60.9572    8.5e+04     -0.001      0.999   -1.67e+05    1.66e+05
# initial_seasonal.30  -230.6923    8.5e+04     -0.003      0.998   -1.67e+05    1.66e+05
# initial_seasonal.31  -270.4807    8.5e+04     -0.003      0.997   -1.67e+05    1.66e+05
# initial_seasonal.32  -195.3533    8.5e+04     -0.002      0.998   -1.67e+05    1.66e+05
# initial_seasonal.33  -127.5602    8.5e+04     -0.002      0.999   -1.67e+05    1.66e+05
# initial_seasonal.34   -89.2780    8.5e+04     -0.001      0.999   -1.67e+05    1.66e+05
# initial_seasonal.35   -85.5887    8.5e+04     -0.001      0.999   -1.67e+05    1.66e+05
# initial_seasonal.36  -141.8220    8.5e+04     -0.002      0.999   -1.67e+05    1.66e+05
# initial_seasonal.37  -118.4590    8.5e+04     -0.001      0.999   -1.67e+05    1.66e+05
# initial_seasonal.38   -13.6496    8.5e+04     -0.000      1.000   -1.67e+05    1.66e+05
# initial_seasonal.39    22.7274    8.5e+04      0.000      1.000   -1.66e+05    1.67e+05
# initial_seasonal.40   109.6876    8.5e+04      0.001      0.999   -1.66e+05    1.67e+05
# initial_seasonal.41    68.1578    8.5e+04      0.001      0.999   -1.66e+05    1.67e+05
# initial_seasonal.42    43.5646    8.5e+04      0.001      1.000   -1.66e+05    1.67e+05
# initial_seasonal.43   109.4614    8.5e+04      0.001      0.999   -1.66e+05    1.67e+05
# initial_seasonal.44   139.6395    8.5e+04      0.002      0.999   -1.66e+05    1.67e+05
# initial_seasonal.45    39.5287    8.5e+04      0.000      1.000   -1.66e+05    1.67e+05
# initial_seasonal.46    54.4515    8.5e+04      0.001      0.999   -1.66e+05    1.67e+05
# initial_seasonal.47   -45.1467    8.5e+04     -0.001      1.000   -1.67e+05    1.66e+05
# initial_seasonal.48    32.7307    8.5e+04      0.000      1.000   -1.66e+05    1.67e+05
# initial_seasonal.49    82.6858    8.5e+04      0.001      0.999   -1.66e+05    1.67e+05
# initial_seasonal.50    63.3239    8.5e+04      0.001      0.999   -1.66e+05    1.67e+05
# initial_seasonal.51          0    8.5e+04          0      1.000   -1.67e+05    1.67e+05
# ===================================================================================
# Ljung-Box (Q):                       65.98   Jarque-Bera (JB):                 2.24
# Prob(Q):                              0.00   Prob(JB):                         0.33
# Heteroskedasticity (H):               0.64   Skew:                            -0.18
# Prob(H) (two-sided):                  0.20   Kurtosis:                         2.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
# [2] Covariance matrix is singular or near-singular, with condition number 6.7e+14. Standard errors may be unstable.

# %%
# Predicciones
model_predict_r = df_w_r_model.predict(fh)
print(model_predict_r)
# Out:
# 2017-08-06    539.011518
# 2017-08-13    556.326036
# 2017-08-20    504.731675
# 2017-08-27    425.543050
# Freq: W-SUN, Name: IsCanceled, dtype: float64

# %%
model_predict_r_ints = df_w_r_model.predict_interval(fh, coverage=0.95) # Crear intervalo de prediccion
model_predict_r_ints
# Out:
#             IsCanceled
#                   0.95
#                  lower       upper
# 2017-08-06  458.494173  619.528864
# 2017-08-13  468.948235  643.703837
# 2017-08-20  410.203270  599.260081
# 2017-08-27  323.749162  527.336939

# %%
# Representar Predicciones
plot_series(y_train, model_predict_r,y_test, labels=["Reserves", "Reserves pred", "Reserves REAL"])
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# (<Figure size 1600x400 with 1 Axes>, <Axes: ylabel='IsCanceled'>)

# %%
fig, ax = plot_series(y_train["2017":], model_predict_r, y_test, labels=["Reserves", "Reserves pred", "Reserves REAL"])
ax.fill_between(
    ax.get_lines()[-2].get_xdata(),
    model_predict_r_ints[('IsCanceled', 0.95, 'lower')],
    model_predict_r_ints[('IsCanceled', 0.95, 'upper')],
    alpha=0.2,
    color=ax.get_lines()[-2].get_c(),
    label=f"95% prediction intervals",
)
ax.legend(loc='upper left');
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Precision de las predicciones

# %% [markdown]
# - MAPE

# %%
from sktime.performance_metrics.forecasting import mean_absolute_percentage_error
# option 1: using the lean function interface
mape_ets_r = mean_absolute_percentage_error(y_test, model_predict_r[0:4])  # Para calcular errores
mape_ets_r
# Out:
# 0.158757438342234

# %%
from sktime.performance_metrics.forecasting import MeanSquaredError
mse = MeanSquaredError()
mse(y_test, model_predict_r[0:4])
# Out:
# 6094.575262635246

# %%
rmse = MeanSquaredError(square_root=True)
rmse(y_test, model_predict_r[0:4]) # Unidades de medida, tiene mas sentido que la primera al no estar elevada al cuadrado
# Out:
# 78.06776071231482

# %% [markdown]
# -------

# %% [markdown]
# # Analisis Cancelaciones

# %%
# Lectura
df_w_c = pd.read_csv('df_cancelaciones.csv')
df_w_c['ArrivalDate'] = pd.to_datetime(df_w_c['ArrivalDate'])
df_w_c = df_w_c.set_index('ArrivalDate')
df_w_c.tail()
# Out:
#              IsCanceled
# ArrivalDate
# 2017-07-30          329
# 2017-08-06          251
# 2017-08-13          275
# 2017-08-20          332
# 2017-08-27          206

# %%
# Graficar Reservas
import seaborn as sns
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(11, 4)})
ax = df_w_c.plot(marker='o', linestyle='-')
ax.set_ylabel('Cancelaciones Hotel');

# %% [markdown]
# Analisis Estacionalidad
#  - Componente estacional, meses con mayores reservas en octubre y descenso de las reservas durante el mes de enero

# %% [markdown]
# ## Modelo de Suavizado Exponencial

# %%
from sktime.forecasting.base import ForecastingHorizon
from sktime.utils.plotting import plot_series
from sktime.forecasting.model_selection import temporal_train_test_split

# %%
# Separamos la muestra entre train y test, vamos a predecir 4 periodos
y_train, y_test = temporal_train_test_split(y =df_w_c["IsCanceled"], test_size=4)
plot_series(y_train, y_test, labels=["y_train", "y_test"])
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# (<Figure size 1600x400 with 1 Axes>, <Axes: ylabel='IsCanceled'>)

# %%
from sktime.forecasting.ets import AutoETS

# %%
# step 2: specifying forecasting horizon
fh = np.arange(1, 5)

# step 3: specifying the forecasting algorithm (4) son los periodos que es trimestral
df_w_c_model = AutoETS(auto=True, sp=52, n_jobs=-1)

# %%
df_w_c_model.fit(y_train) # Se estima con los datos de train SO LO
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# AutoETS(auto=True, n_jobs=-1, sp=52)

# %%
print(df_w_c_model.summary())
# Out:
#                                  ETS Results
# ==============================================================================
# Dep. Variable:             IsCanceled   No. Observations:                  105
# Model:                       ETS(ANA)   Log Likelihood                -573.446
# Date:                Thu, 21 Dec 2023   AIC                           1258.893
# Time:                        10:35:52   BIC                           1407.514
# Sample:                    08-02-2015   HQIC                          1319.117
#                          - 07-30-2017   Scale                         3245.127
# Covariance Type:               approx
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# smoothing_level         0.4368      0.096      4.544      0.000       0.248       0.625
# smoothing_seasonal   5.632e-05        nan        nan        nan         nan         nan
# initial_level         172.7063        nan        nan        nan         nan         nan
# initial_seasonal.0    -12.7704        nan        nan        nan         nan         nan
# initial_seasonal.1     18.3912        nan        nan        nan         nan         nan
# initial_seasonal.2     58.1157        nan        nan        nan         nan         nan
# initial_seasonal.3    113.2454        nan        nan        nan         nan         nan
# initial_seasonal.4     66.0295        nan        nan        nan         nan         nan
# initial_seasonal.5    225.7643        nan        nan        nan         nan         nan
# initial_seasonal.6    224.1079        nan        nan        nan         nan         nan
# initial_seasonal.7    174.3295        nan        nan        nan         nan         nan
# initial_seasonal.8    125.3078        nan        nan        nan         nan         nan
# initial_seasonal.9    298.7398        nan        nan        nan         nan         nan
# initial_seasonal.10   111.2238        nan        nan        nan         nan         nan
# initial_seasonal.11   195.8228        nan        nan        nan         nan         nan
# initial_seasonal.12   223.6187        nan        nan        nan         nan         nan
# initial_seasonal.13   179.4704        nan        nan        nan         nan         nan
# initial_seasonal.14   171.4483        nan        nan        nan         nan         nan
# initial_seasonal.15   210.8735        nan        nan        nan         nan         nan
# initial_seasonal.16    11.8901        nan        nan        nan         nan         nan
# initial_seasonal.17   107.1126        nan        nan        nan         nan         nan
# initial_seasonal.18   116.3722        nan        nan        nan         nan         nan
# initial_seasonal.19   -28.3622        nan        nan        nan         nan         nan
# initial_seasonal.20    20.8824        nan        nan        nan         nan         nan
# initial_seasonal.21    81.3349        nan        nan        nan         nan         nan
# initial_seasonal.22    94.1157        nan        nan        nan         nan         nan
# initial_seasonal.23   -35.4328        nan        nan        nan         nan         nan
# initial_seasonal.24   -50.7017        nan        nan        nan         nan         nan
# initial_seasonal.25    10.8765        nan        nan        nan         nan         nan
# initial_seasonal.26   -23.6093        nan        nan        nan         nan         nan
# initial_seasonal.27   -44.9246        nan        nan        nan         nan         nan
# initial_seasonal.28   -74.1443        nan        nan        nan         nan         nan
# initial_seasonal.29    74.9493        nan        nan        nan         nan         nan
# initial_seasonal.30   -83.1423        nan        nan        nan         nan         nan
# initial_seasonal.31  -112.9044        nan        nan        nan         nan         nan
# initial_seasonal.32    46.4251        nan        nan        nan         nan         nan
# initial_seasonal.33    33.6723        nan        nan        nan         nan         nan
# initial_seasonal.34   -50.3278        nan        nan        nan         nan         nan
# initial_seasonal.35   -57.1265        nan        nan        nan         nan         nan
# initial_seasonal.36    37.7997        nan        nan        nan         nan         nan
# initial_seasonal.37    84.5129        nan        nan        nan         nan         nan
# initial_seasonal.38   114.2505        nan        nan        nan         nan         nan
# initial_seasonal.39    78.3489        nan        nan        nan         nan         nan
# initial_seasonal.40   325.1002        nan        nan        nan         nan         nan
# initial_seasonal.41   199.8628        nan        nan        nan         nan         nan
# initial_seasonal.42   226.1817        nan        nan        nan         nan         nan
# initial_seasonal.43   169.2058        nan        nan        nan         nan         nan
# initial_seasonal.44   231.5613        nan        nan        nan         nan         nan
# initial_seasonal.45   148.7890        nan        nan        nan         nan         nan
# initial_seasonal.46    83.2417        nan        nan        nan         nan         nan
# initial_seasonal.47    87.1034        nan        nan        nan         nan         nan
# initial_seasonal.48    62.7695        nan        nan        nan         nan         nan
# initial_seasonal.49   189.1347        nan        nan        nan         nan         nan
# initial_seasonal.50   101.9391        nan        nan        nan         nan         nan
# initial_seasonal.51          0        nan        nan        nan         nan         nan
# ===================================================================================
# Ljung-Box (Q):                       34.07   Jarque-Bera (JB):                 0.38
# Prob(Q):                              0.04   Prob(JB):                         0.82
# Heteroskedasticity (H):               0.99   Skew:                             0.02
# Prob(H) (two-sided):                  0.98   Kurtosis:                         2.71
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
# [2] Covariance matrix is singular or near-singular, with condition number 1.55e+14. Standard errors may be unstable.

# %%
# Predicciones
model_predict_c = df_w_c_model.predict(fh)
print(model_predict_c)
# Out:
# 2017-08-06    398.123866
# 2017-08-13    485.319424
# 2017-08-20    358.954515
# 2017-08-27    383.288371
# Freq: W-SUN, Name: IsCanceled, dtype: float64

# %%
model_predict_c_ints = df_w_c_model.predict_interval(fh, coverage=0.95) # Crear intervalo de prediccion
model_predict_c_ints
# Out:
#             IsCanceled
#                   0.95
#                  lower       upper
# 2017-08-06  286.472522  509.775210
# 2017-08-13  363.480676  607.158171
# 2017-08-20  227.716799  490.192230
# 2017-08-27  243.281244  523.295499

# %%
# Representar Predicciones
plot_series(y_train, model_predict_c,y_test, labels=["Reserves", "Reserves pred", "Reserves REAL"])
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# (<Figure size 1600x400 with 1 Axes>, <Axes: ylabel='IsCanceled'>)

# %%
fig, ax = plot_series(y_train["2017":], model_predict_c, y_test, labels=["Reserves", "Reserves pred", "Reserves REAL"])
ax.fill_between(
    ax.get_lines()[-2].get_xdata(),
    model_predict_c_ints[('IsCanceled', 0.95, 'lower')],
    model_predict_c_ints[('IsCanceled', 0.95, 'upper')],
    alpha=0.2,
    color=ax.get_lines()[-2].get_c(),
    label=f"95% prediction intervals",
)
ax.legend(loc='upper left');
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/codespace/.python/current/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Precision de las predicciones

# %% [markdown]
# - MAPE

# %%
from sktime.performance_metrics.forecasting import mean_absolute_percentage_error
# option 1: using the lean function interface
mape_ets_c = mean_absolute_percentage_error(y_test, model_predict_c[0:4])  # Para calcular errores
mape_ets_c
# Out:
# 0.5731900557465301

# %%
from sktime.performance_metrics.forecasting import MeanSquaredError
mse = MeanSquaredError()
mse(y_test, model_predict_c[0:4])
# Out:
# 24509.351087379993

# %%
rmse = MeanSquaredError(square_root=True)
rmse(y_test, model_predict_c[0:4]) # Unidades de medida, tiene mas sentido que la primera al no estar elevada al cuadrado
# Out:
# 156.55462652818662

# %%
mape_reservas = pd.read_csv('mape_reservas.csv')
mape_reservas = mape_reservas.drop(columns='Unnamed: 0')
nuevo_registro = pd.DataFrame({'Modelo_Reservas': ['ETS'], 'MAPE': [mape_ets_r]})
mape_reservas = pd.concat([mape_reservas, nuevo_registro], ignore_index=True)
mape_reservas
# Out:
#   Modelo_Reservas      MAPE
# 0           ARIMA  0.086322
# 1             ETS  0.158757

# %%
mape_cancelaciones = pd.read_csv('mape_cancelaciones.csv')
mape_cancelaciones = mape_cancelaciones.drop(columns='Unnamed: 0')
nuevo_registro = pd.DataFrame({'Modelo_Cancelaciones': ['ETS'], 'MAPE': [mape_ets_c]})
mape_cancelaciones = pd.concat([mape_cancelaciones, nuevo_registro], ignore_index=True)
mape_cancelaciones
# Out:
#   Modelo_Cancelaciones      MAPE
# 0                ARIMA  0.251014
# 1                  ETS  0.573190

# %%
mape_reservas.to_csv('mape_reservas.csv')

# %%
mape_cancelaciones.to_csv('mape_cancelaciones.csv')

# %% [markdown]
# ------
